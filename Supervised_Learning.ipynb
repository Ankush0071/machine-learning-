# %% [markdown]
# # Train Test Split

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Boston.csv")
dataset.head(3)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7

# %%
dataset.shape
# Out:
# (506, 15)

# %%
input_data = dataset.iloc[:,:-1]
output_data = dataset["medv"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.25)

# %%
x_train
# Out:
#      Unnamed: 0      crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 383         384   7.99248  0.0  18.10     0  0.700  5.520  100.0  1.5331   24
# 438         439  13.67810  0.0  18.10     0  0.740  5.935   87.9  1.8206   24
# 490         491   0.20746  0.0  27.74     0  0.609  5.093   98.0  1.8226    4
# 95           96   0.12204  0.0   2.89     0  0.445  6.625   57.8  3.4952    2
# 377         378   9.82349  0.0  18.10     0  0.671  6.794   98.8  1.3580   24
# ..          ...       ...  ...    ...   ...    ...    ...    ...     ...  ...
# 33           34   1.15172  0.0   8.14     0  0.538  5.701   95.0  3.7872    4
# 4             5   0.06905  0.0   2.18     0  0.458  7.147   54.2  6.0622    3
# 421         422   7.02259  0.0  18.10     0  0.718  6.006   95.3  1.8746   24
# 142         143   3.32105  0.0  19.58     1  0.871  5.403  100.0  1.3216    5
# 3             4   0.03237  0.0   2.18     0  0.458  6.998   45.8  6.0622    3
#
#      tax  ptratio   black  lstat
# 383  666     20.2  396.90  24.56
# 438  666     20.2   68.95  34.02
# 490  711     20.1  318.43  29.68
# 95   276     18.0  357.98   6.65
# 377  666     20.2  396.90  21.24
# ..   ...      ...     ...    ...
# 33   307     21.0  358.77  18.35
# 4    222     18.7  396.90   5.33
# 421  666     20.2  319.98  15.70
# 142  403     14.7  396.90  26.82
# 3    222     18.7  394.63   2.94
#
# [379 rows x 14 columns]

# %%
x_train.shape , y_train.shape
# Out:
# ((379, 14), (379,))

# %%
x_test.shape , y_test.shape
# Out:
# ((127, 14), (127,))

# %% [markdown]
# # Regression Analysis (LINEAR REGRESSION)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("placement.csv")
dataset.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="cgpa", y="package",data=dataset)
plt.show()

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x = dataset[["cgpa"]]
y = dataset["package"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[6.89]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.92962016])

# %%
lr.score(x_test,y_test)
# Out:
# 0.7730984312051673

# %%
y_prd = lr.predict(x)

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa", y="package",data=dataset)
plt.plot(dataset["cgpa"],y_prd,c="red")
plt.legend(["org data" , "predict line"])
plt.show()
