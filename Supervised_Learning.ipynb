# %% [markdown]
# # Train Test Split

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Boston.csv")
dataset.head(3)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7

# %%
dataset.shape
# Out:
# (506, 15)

# %%
input_data = dataset.iloc[:,:-1]
output_data = dataset["medv"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.25)

# %%
x_train
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 80           81   0.04113  25.0   4.86     0  0.426  6.727   33.5  5.4007
# 379         380  17.86670   0.0  18.10     0  0.671  6.223  100.0  1.3861
# 437         438  15.17720   0.0  18.10     0  0.740  6.152  100.0  1.9142
# 114         115   0.14231   0.0  10.01     0  0.547  6.254   84.2  2.2565
# 252         253   0.08221  22.0   5.86     0  0.431  6.957    6.8  8.9067
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 356         357   8.98296   0.0  18.10     1  0.770  6.212   97.4  2.1222
# 180         181   0.06588   0.0   2.46     0  0.488  7.765   83.3  2.7410
# 324         325   0.34109   0.0   7.38     0  0.493  6.415   40.1  4.7211
# 318         319   0.40202   0.0   9.90     0  0.544  6.382   67.2  3.5325
# 191         192   0.06911  45.0   3.44     0  0.437  6.739   30.8  6.4798
#
#      rad  tax  ptratio   black  lstat
# 80     4  281     19.0  396.90   5.29
# 379   24  666     20.2  393.74  21.78
# 437   24  666     20.2    9.32  26.45
# 114    6  432     17.8  388.74  10.45
# 252    7  330     19.1  386.09   3.53
# ..   ...  ...      ...     ...    ...
# 356   24  666     20.2  377.73  17.60
# 180    3  193     17.8  395.56   7.56
# 324    5  287     19.6  396.90   6.12
# 318    4  304     18.4  395.21  10.36
# 191    5  398     15.2  389.71   4.69
#
# [379 rows x 14 columns]

# %%
x_train.shape , y_train.shape
# Out:
# ((379, 14), (379,))

# %%
x_test.shape , y_test.shape
# Out:
# ((127, 14), (127,))

# %% [markdown]
# # Regression Analysis (LINEAR REGRESSION)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("placement.csv")
dataset.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="cgpa", y="package",data=dataset)
plt.show()

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x = dataset[["cgpa"]]
y = dataset["package"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[6.89]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.92962016])

# %%
lr.score(x_test,y_test)
# Out:
# 0.7730984312051673

# %%
y_prd = lr.predict(x)

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa", y="package",data=dataset)
plt.plot(dataset["cgpa"],y_prd,c="red")
plt.legend(["org data" , "predict line"])
plt.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Salary_Data.csv")
dataset.head(3)
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731

# %%
dataset.shape
# Out:
# (30, 3)

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()
